# %% [markdown]
# ### 필요한 libary들 import

# %%
import os
import numpy as np
import pandas as pd
# import pymysql
# import matplotlib.pyplot as plt
import json
import uuid
import bcrypt
# !pip install bcrypt
# !pip install PyMySQL
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.12.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.1
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# binaryornot                        0.4.4
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# bokeh                              2.3.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cachetools                         4.2.2
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# cmake                              3.18.4.post1
# colorama                           0.4.4
# comtypes                           1.1.9
# conda                              4.10.1
# conda-build                        3.21.4
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.3
# conda-token                        0.2.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       3.4.7
# cuda                               0.0.1
# cycler                             0.10.0
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          4.4.2
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docutils                           0.16
# easyocr                            1.3.1
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# flatbuffers                        1.12
# fsspec                             0.9.0
# future                             0.18.2
# gast                               0.4.0
# gevent                             21.1.2
# glob2                              0.7
# gmpy2                              2.0.8
# google-auth                        1.30.0
# google-auth-oauthlib               0.4.4
# google-pasta                       0.2.0
# greenlet                           1.0.0
# grpcio                             1.37.1
# h5py                               3.1.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imagecodecs                        2021.3.31
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# inexactsearch                      1.0.2
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# joblib                             1.0.1
# JPype1                             1.2.0
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: You are using pip version 21.1.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Yun\anaconda3\python.exe -m pip install --upgrade pip' command.
# Keras                              2.4.3
# keras-nightly                      2.6.0.dev2021050100
# Keras-Preprocessing                1.1.2
# keyring                            22.3.0
# kiwisolver                         1.3.1
# konlpy                             0.5.2
# kss                                2.5.0
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# lmdb                               1.2.1
# locket                             0.2.1
# lxml                               4.6.3
# Markdown                           3.3.4
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# mecab-python                       0.996-ko-0.9.2-msvc
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# natsort                            7.1.1
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5.1
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.19.5
# numpydoc                           1.1.0
# oauthlib                           3.1.0
# olefile                            0.46
# opencv-python                      4.5.1.48
# openpyxl                           3.0.7
# opt-einsum                         3.3.0
# packaging                          20.9
# pandas                             1.2.4
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                21.1.1
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# poyo                               0.5.0
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# protobuf                           3.15.8
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# py-hanspell                        1.1
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.8.1
# pykospacing                        0.4
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pyspellchecker                     0.7.1
# pytesseract                        0.3.7
# pytest                             6.2.3
# python-bidi                        0.4.2
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# python-slugify                     4.0.1
# pytz                               2021.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# requests-oauthlib                  1.3.0
# rope                               0.18.0
# rsa                                4.7.2
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.6.3
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# setuptools                         56.0.0
# silpa-common                       0.3
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.15.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soundex                            1.1.3
# soupsieve                          2.2.1
# soynlp                             0.0.493
# spellchecker                       0.4
# Sphinx                             3.5.4
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             5.0.0
# spyder-kernels                     2.0.1
# SQLAlchemy                         1.4.7
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tb-nightly                         2.6.0a20210501
# tblib                              1.7.0
# tensorboard                        2.5.0
# tensorboard-data-server            0.6.0
# tensorboard-plugin-wit             1.8.0
# tensorflow-estimator               2.4.0
# termcolor                          1.1.0
# terminado                          0.9.4
# testpath                           0.4.4
# text-unidecode                     1.3
# textdistance                       4.2.1
# tf-estimator-nightly               2.5.0.dev2021032601
# tf-nightly                         2.6.0.dev20210501
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# tinycss                            0.4
# toml                               0.10.2
# toolz                              0.11.1
# torch                              1.8.1
# torchaudio                         0.8.1
# torchvision                        0.9.1
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# tweepy                             3.10.0
# typed-ast                          1.4.2
# typing-extensions                  3.7.4.3
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# urllib3                            1.26.4
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0

# %%
! pip install bcrypt
# Out:
# Requirement already satisfied: bcrypt in c:\users\yun\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: six>=1.4.1 in c:\users\yun\appdata\roaming\python\python38\site-packages (from bcrypt) (1.15.0)
# Requirement already satisfied: cffi>=1.1 in c:\users\yun\anaconda3\lib\site-packages (from bcrypt) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\yun\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt) (2.20)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\yun\appdata\roaming\python\python38\site-packages)
# WARNING: You are using pip version 21.1.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Yun\anaconda3\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# #### 카테고리 한글 번역

# %%
category = []
category.append(["Topwear", "상의"])
category.append(["Bottomwear", "하의"])
category.append(["Dress", "원피스"])
category.append(["Footwear", "신발"])
category.append(["Bags", "가방"])
category.append(["Accessories", "액세서리"])

# 0: 상의, 1: 하의, 2: 원피스, 3: 신발, 4: 가방, 5: 액세서리

article_dict = {}
article_dict[80] = [0, 0, "Blazers", "블레이저"]
article_dict[82] = [0, 1, "Jackets", "재킷"]
article_dict[85] = [0, 2, "Shirts", "셔츠"]
article_dict[87] = [0, 3, "Sweatshirts", "스웨트 셔츠"]
article_dict[88] = [0, 4, "Sweaters", "스웨터"]
article_dict[89] = [0, 5, "Tops", "여성 상의"]
article_dict[90] = [0, 6, "Tshirts", "티셔츠"]
article_dict[91] = [0, 7, "Tunics", "튜닉"]
article_dict[133] = [0, 8, "Waistcoat", "조끼"]
article_dict[176] = [0, 9, "Suspenders", "멜빵"]

article_dict[204] = [0, 10, "Rompers", "롬퍼"]
article_dict[273] = [0, 11, "Shrug", "슈러그"]
article_dict[70] = [1, 12, "Jeans", "청바지"]
article_dict[71] = [1, 13, "Leggings", "레깅스"]
article_dict[72] = [1, 14, "Shorts", "반바지"]
article_dict[74] = [1, 15, "Skirts", "치마"]
article_dict[76] = [1, 16, "Track Pants", "트랙 팬츠"]
article_dict[77] = [1, 17, "Tracksuits", "트랙 수트"]
article_dict[78] = [1, 18, "Trousers", "정장 바지"]
article_dict[145] = [1, 19, "Stockings", "스타킹"]

article_dict[173] = [1, 20, "Tights", "타이즈"]
article_dict[249] = [1, 21, "Jeggings", "제깅스"]
article_dict[272] = [1, 22, "Rain Trousers", "방수 바지"]
article_dict[75] = [2, 23, "Swimwear", "수영복"]
article_dict[79] = [2, 24, "Dresses", "원피스"]
article_dict[207] = [2, 25, "Jumpsuit", "점프수트"]
article_dict[92] = [3, 26, "Sandals", "샌들"]
article_dict[93] = [3, 27, "Casual Shoes", "캐주얼 신발"]
article_dict[94] = [3, 28, "Formal Shoes", "정장 신발"]
article_dict[95] = [3, 29, "Sports Shoes", "스포츠 신발"]

article_dict[127] = [3, 30, "Flip Flops", "플립 플롭"]
article_dict[279] = [3, 31, "Heels", "힐"]
article_dict[280] = [3, 32, "Flats", "플랫"]
article_dict[283] = [3, 33, "Sports Sandals", "스포츠 샌들"]
article_dict[43] = [4, 34, "Backpacks", "백팩"]
article_dict[45] = [4, 35, "Clutches", "클러치 백"]
article_dict[46] = [4, 36, "Handbags", "핸드 백"]
article_dict[65] = [4, 37, "Wallets", "지갑"]
article_dict[120] = [4, 38, "Duffel Bag", "더플 백"]
article_dict[158] = [4, 39, "Laptop Bag", "노트북 가방"]

article_dict[167] = [4, 40, "Travel Accessory", "여행용 파우치"]
article_dict[168] = [4, 41, "Waist Pouch", "허리 백"]
article_dict[170] = [4, 42, "Rucksacks", "배낭"]
article_dict[171] = [4, 43, "Mobile Pouch", "휴대폰 파우치"]
article_dict[172] = [4, 44, "Trolley Bag", "캐리어"]
article_dict[284] = [4, 45, "Messenger Bag", "메신저 가방"]
article_dict[395] = [4, 46, "Tablet Sleeve", "태블릿 파우치"]
article_dict[49] = [5, 47, "Belts", "벨트"]
article_dict[54] = [5, 48, "Caps", "캡"]
article_dict[56] = [5, 49, "Scarves", "스카프"]

article_dict[59] = [5, 50, "Mufflers", "머플러"]
article_dict[61] = [5, 51, "Socks", "양말"]
article_dict[62] = [5, 52, "Stoles", "스톨"]
article_dict[63] = [5, 53, "Ties", "넥타이"]
article_dict[121] = [5, 54, "Headband", "머리 밴드"]
article_dict[202] = [5, 55, "Booties", "아기 양말"]
article_dict[209] = [5, 56, "Hat", "햇"]


usage = {}
usage["Casual"] = [0, "캐주얼"]
usage["Ethnic"] = [1, "에스닉"]
usage["Formal"] = [2, "포멀"]
usage["Home"] = [3, "집"]
usage["Party"] = [4, "파티"]
usage["Smart Casual"] = [5, "스마트 캐주얼"]
usage["Sports"] = [6, "스포츠"]
usage["Travel"] = [7, "여행"]
usage["NA"] = [8, "기타"]


age_gender_group = {}
age_gender_group["Adults-Men"] = [0, "성인 남성"]
age_gender_group["Adults-Women"] = [1, "성인 여성"]
age_gender_group["Adults-Unisex"] = [2, "성인 남녀 겸용"]
age_gender_group["Kids-Boys"] = [3, "남자 아이"]
age_gender_group["Kids-Girls"] = [4, "여자 아이"]
age_gender_group["Kids-Unisex"] = [5, "어린이 남녀 겸용"]


color = {}
color["Beige"] = [0, "베이지"]
color["Black"] = [1, "검정"]
color["Blue"] = [2, "파랑"]
color["Bronze"] = [3, "브론즈"]
color["Brown"] = [4, "갈색"]
color["Burgundy"] = [5, "버건디"]
color["Charcoal"] = [6, "차콜"]
color["Coffee Brown"] = [7, "커피브라운"]
color["Copper"] = [8, "구리"]
color["Cream"] = [9, "크림"]

color["Fluorescent Green"] = [10, "형광 초록"]
color["Gold"] = [11, "금색"]
color["Green"] = [12, "초록"]
color["Grey"] = [13, "회색"]
color["Grey Melange"] = [14, "멜란지 그레이"]
color["Khaki"] = [15, "카키"]
color["Lavender"] = [16, "라벤더"]
color["Lime Green"] = [17, "라임"]
color["Magenta"] = [18, "마젠타"]
color["Maroon"] = [19, "고동색"]

color["Mauve"] = [20, "모브색"]
color["Metallic"] = [21, "메탈"]
color["Multi"] = [22, "여러 색"]
color["Mushroom Brown"] = [23, "머쉬룸"]
color["Mustard"] = [24, "머스타드"]
color["Navy Blue"] = [25, "감색"]
color["Nude"] = [26, "누드"]
color["Off White"] = [27, "오프 화이트"]
color["Olive"] = [28, "올리브색"]
color["Orange"] = [29, "주황"]

color["Peach"] = [30, "피치"]
color["Pink"] = [31, "핑크"]
color["Purple"] = [32, "보라"]
color["Red"] = [33, "빨강"]
color["Rose"] = [34, "장미색"]
color["Rust"] = [35, "적갈색"]
color["Sea Green"] = [36, "해록색"]
color["Silver"] = [37, "은색"]
color["Skin"] = [38, "스킨색"]
color["Steel"] = [39, "흑철색"]

color["Tan"] = [40, "황갈색"]
color["Taupe"] = [41, "회갈색"]
color["Teal"] = [42, "암청색"]
color["Turquoise Blue"] = [43, "청록색"]
color["White"] = [44, "하양"]
color["Yellow"] = [45, "노랑"]
color["NA"] = [46, "없음"]

season = {}
season["Spring"] = "SPR"
season["Summer"] = "SUM"
season["Fall"] = "FAL"
season["Winter"] = "WIN"

# %% [markdown]
# ### DB 접근 정보

# %%
sql_str = 'SET AUTOCOMMIT = FALSE;\n'

# %% [markdown]
# #### PROVIDER & STORE INSERT

# %%
fashion_brand_info_path = "fashion_brand_info.xlsx"
# raw_data = pd.read_csv(raw_input_path, sep="", encoding="UTF-8")
brand_data = pd.read_excel(fashion_brand_info_path)
logo_url = "https://avocado-img.s3.ap-northeast-2.amazonaws.com/avocado_logo.png"
brand_data["brand_user_img_url"] = brand_data["brand_user_img_url"].fillna(logo_url)

display(brand_data)
print(brand_data.iloc[1]['brandName'])
# Out:
#       brandName                                 brand_user_img_url
# 0     Palm Tree  https://avocado-img.s3.ap-northeast-2.amazonaw...
# 1          Nike  http://assets.myntassets.com/v1/assets/banners...
# 2    LOCOMOTIVE  http://assets.myntassets.com/assets/images/201...
# 3        Reebok  http://assets.myntassets.com/assets/images/201...
# 4          Puma  http://assets.myntassets.com/assets/images/201...
# ..          ...                                                ...
# 257     Rocky S  https://avocado-img.s3.ap-northeast-2.amazonaw...
# 258     Hakashi  https://avocado-img.s3.ap-northeast-2.amazonaw...
# 259     Avirate  http://assets.myntassets.com/assets/images/201...
# 260    MEGADETH  https://avocado-img.s3.ap-northeast-2.amazonaw...
# 261      Scholl  https://avocado-img.s3.ap-northeast-2.amazonaw...
#
# [262 rows x 2 columns]
# Nike

# %% [markdown]
# ##### 스토어 등록

# %%
banner_base_url = "https://avocado-img.s3.ap-northeast-2.amazonaws.com/brand_background/brand_background_"
banners = ["1.png", "2.png", "3.png", "4.png", "5.png", "6.png", "7.png", "8.png", "9.png", "10.png"]
store_uuids = ['2fe2b6febfbf40d49517b2af0d6e0052',
'798bdcef526d476bb17db577c095da3c',
'0b55eec8b5014020acc65c9b45010d44',
'23d83c830df74f82acded17b1ae3df09',
'35e94b0c3c504d7cad176dbec3ea5626',
'bc794748e6b64d5192c25afe0a9ac413',
'7e8b3142dd9c44b5876c102dda41a384',
'2c5f79f2690944ed8be10b0b57df694a',
'e5f2daa83e274e4e87aebaa1f3f163a5',
'b4265a04c4bd484889b1e93a872ffe90',
'9e0d88e4c6284249a498efd3668407d4',
'41c5e18665974cae88e38b8671102f50',
'623cb69a1a8e424b854b590ba147419c',
'b31cffe898784ac49595391f8cd09356',
'bfdd516dc58e49d9a1a916ea160a5e46',
'5a4c6074737b4638b0b7605a23284975',
'08b754a63b2f4ef1bdc8ba857f3c0f29',
'c7c4aaffc13e48a6b439011bfb3bdef7',
'f722ed3613284e72a41755e226c983fa',
'f131642faaa240179c203b13ead44e98',
'b56b0b12feba4069885ffbef6a4d1e1d',
'3f62292302e24602a272cf19ac621e21',
'7fae577dd4f24b28be3c0de1ab7f8d97',
'b675cd00fee94181bdbbfdd740c0414e',
'5337192002d2475d821b37d7b023bb11',
'2d323455513f4310a7662174ef5ca88f',
'806532bb3f604778b28d08f2a205dc30',
'8bf2c172e9d543809d88f7db5e948aa9',
'9d5f5f914270409390716098d94339d3',
'2848b786560d4cc18ce478ddf51d2f06',
'983350f5d0bb4e26abd386f534fee12a',
'5504925dc8c44022b285dcda79dc5875',
'33ff9c46a1724d61ab46d2d320a95f16',
'7da30fc012c94ca3b546e8eee143e79b',
'faa373f6adab46d8a6e2e8a0409cbee7',
'c380016f1a0a4a628185961d256fa62f',
'cf9209fd6c9a41f097979775d19f05e6',
'3b4faf3fbf8045a9804cb6d582b7f3ca',
'eb566a23f5cb4a81930dfc77f6af0543',
'fc16a8b85dce4acb94afe9d44a54bd8a',
'ce88c0a1944e4baca1aaf3fb96f3a9ab',
'18ee419344e84d518130ea7fa470e01a',
'4e6ed7c6f15040beb888eca80da59fbb',
'62adae397e9c4a10bc280db984611052',
'effd2bec68b5431bb7b2d86438aa9ef4',
'84f56414f0c24b5bb8fc47ba8b4d64f0',
'4d4bc793f005490891631aa39455ee6b',
'9f67e3073d6c4d1e906ad1b8eeacb7f1',
'5475093cacc3479ca2cd9739aa8e3e1c',
'371c7d33ae1a4772af2e020834ee1445',
'345169a2541443ea8e642aa61a24fd7d',
'b582d0cdbae846049631f6d475a8b38b',
'ed6dbf8ee9dd40f3b7442971a2185d9e',
'abc73a98caf948dcb7d964d8d6c03caa',
'db75e7c1d1ea4ffba8c81d9cbd840628',
'4c34c97b3c3d4ba4b49aa853b38baa2f',
'8ff4b86beb23498a9247405635166cd8',
'06a614f05d7f4afd81f964e857554805',
'f61562c4517a47cabe0d5ebb99a180bf',
'f20feda7b2f845b2884774213323edf6',
'f292a195b34c4d62853f76c4860d9ec4',
'bc73c933e3c44b4d971e499215f94844',
'7a02811d48c84c3f9372b939fcba109b',
'37137e21075a4c43b004987934c2eade',
'e848c07ebf1d4a3d84647dd3b284e179',
'65b8f6cded8748619544ca732a7ec301',
'c96ae42853c845dbaac3d33968dc1911',
'da2727f3570a4eabafa5ea40183a7d9d',
'9873d4f4cd6843c498fd0d35ec497b80',
'b67cc7fbcd9447a999e8f6c32c915dcb',
'37cb8c06b7364272a916297542a44335',
'17ba2706fe364efe9ebda9f2fd219506',
'0ae0035320464f4fb6532c931cae7ad3',
'a27659805f8a40d89de1c2eea1df91b4',
'4d42b516fe274a4793c7d0aa07fbb0af',
'eddfbb2a7a834264adb3e923d1b50586',
'1366fce6682e46f289510cb501902096',
'dffb3d98963f4f24ac9a07cdc812a23e',
'0ce618210a8f48338c417ff8c58a6125',
'2ff5f39afab34029bf7e848683046c1f',
'f4aaed518e6a44008548a629959eff1e',
'2abc67ede9af462285118d53f92b3d6d',
'c77b5d5aae214c55b882f82599cd72a5',
'7cf2ca0dcdf24dd2b9902e4c6f08547c',
'984b9e72facf43a6b4fe6432696b2a25',
'617f9507aaed422fb89714b36e07ecaa',
'4e93885d611e49108094eeb98d1388a7',
'5f470082bfcb42cab88aa60a66e9b428',
'96eb4081140d49239c8aa3c16fe0e19c',
'fc152965226449c0a9d7b37638c8300f',
'1ffb0c009c2a4c42906ebc8aa4d41e98',
'e3d2877deb2349d1b394c504a5a178c9',
'd31e7dc543654dc6bc61cbc32c713473',
'ab6729cc0a8e4c6794cc68d2d0a7f6d0',
'940186abae8c4683872f5ab03155bf76',
'fb94f7004d8a4e1ab45e2c6711cf27ff',
'a9d61af65a684ef6a1ebbd63e5936a80',
'3201d16d4eee436ca5747a135d51cdf2',
'9526cfd7767c45db8455cfec60a706ff',
'0c88ac262e344c3e8b1d0ace7ec915ea',
'0b8bfa4015fb411594e4796352f4181a',
'39c5880673054a58ae374d190252083c',
'48b91a1d659a4688a46adb043ae38221',
'a29e59fbb1834617bc1b4a4e48627c04',
'1f0963b429204ce7b597071292ce26f6',
'c5b335f6127b42e7a33265ebab6e4249',
'6089bd0c16074c5c9f4960129eca75a7',
'e24d8081f3b849eeb60f368d603de9b1',
'08419c480c03492a92f6dcab024d1ecd',
'13957b642aa04ce1a68e8112ac3c86c5',
'cf549aacf3d04e0298d9b17c76dd9a1d',
'2357915085bf4162ba1ae2dc6fa64323',
'48ce8c4d0301470f95dff9bf5be053f7',
'7dbcc5177e614385b32269dc9a8727a3',
'5f78629cb05e4ef29aadb3c54ca96199',
'9afa1f646257465f8f37dca7aefd87ce',
'2c3126f6fd8f4be0bb5c090675d8c684',
'c1b34f14195f41ab84a822f832dd0b98',
'37f4ee109bb84b708d48ddc0706b39f8',
'14432ac7c3b649149414e749477f4ad6',
'9e2610ca516d4935ac3cee1b58f6f290',
'7f7f197a1a014424a817582571ce96d0',
'177a551e652341b3b5f69187d3626379',
'06c8145645d64f809b02bf133b528890',
'aa96c5d2c9b54448b21dadb37c3871e3',
'f037303106e24aa4888382c6b94a7bc3',
'c17b419965af4f48aaa9835984f7634e',
'6807efc7f3a54adfa84ce065e4979259',
'b1a1e71211e74efb95e5c9685174632f',
'a3ae668ba5b34bf7a1f649a15e054095',
'5feb9e26f2814e718d873724b08d95c5',
'9e6a7b8c8e7040289096283736153f6d',
'61be0ad8402747d3890e30eed0a1d227',
'19d5d863cf334e20a104e03cc18a3b8b',
'437ef861e9194fdcb505072f3c0a6125',
'e1375072eab24f55bbd2582ba8e4e70f',
'd3789ba2156f4cbb816d996a120ad6aa',
'51432de0415b41cca65cae6bd92e1a1d',
'9e6bb0ca121b4bc69722058867c1209e',
'9c9f090aa6d94577b3fffb2877c0545f',
'1f7829aa68964ed38ae5addccf571e8e',
'2f647082353441a58809ef11e7a07672',
'85d07311b1ea488da3bbcd1a11891ff4',
'f546b56db7fc4af19af583de4ee27883',
'7a7a55500d884bca886fd0782febef56',
'872945ce4586453cb07b918cf1a4144e',
'59b50af286af468b9f62542a3d448359',
'382068a506f945719742fc6a76de9242',
'c88f370a271347198c6aa354f716bae4',
'df69fd6a61bc4189b2bdd912b3a66387',
'680ac9c381e346d7819cdd0623a5e1c6',
'c15a7265e950404eaf1d9efdfd9a2a58',
'46d8908445e443a2b0cef3a9ce48e111',
'd142cdf19bff4edcba755c2d583562b7',
'71e20319736d423ca19592a433175ad4',
'f53c25e9468c4cb496c1420b872fa654',
'4967e7b5c64742168d536bb54e746361',
'17ee04fbb06e43aeb03c14881589aed0',
'16853cde3cf7416d964d06181c3952a4',
'3785d432c2924856895803fbdfc2b5bd',
'8c5302e480744937b4ed33eec5da04fb',
'7c30aafccd554d33b8bb35a6b741a920',
'2679f47ec95a4c558f332b495c02b0f1',
'5238750ec6a34183bb15fc5004017142',
'1d9452b669714c5b9743cb053a09977f',
'ae8c01b49e3c4b0f80fa43edf31f4041',
'9cfb606ed2b14f87858e52ea7f3a156e',
'f5acb8f4cd2242fa9dc1532b986f73af',
'3a4c200ad1d043d696ba09e47da64c93',
'c20dd3904b124075bc4f0565ea4af907',
'5983e2aeffbb46bc9711aca6a437e2aa',
'4fea71e43d1d4a9d8e50d964b0bc0ff2',
'323392c92a834846a62975138dafe57a',
'3a0507b499c34692adacffbdd886343e',
'fe99e54a8b3742ec8781b7f88a198f80',
'43b357bf8c954eefa90c36f67314dfa6',
'9f9c55c9bf6b4a6dba3164bb1300507d',
'3ddd757b91084735bfcdfcfb6fca65a8',
'08868c5610a44bf3ab7bce3852f0d541',
'0bab3bc65e7d4f9bbf7763dcb917d069',
'394b2d92f5604a5cac12bb2faf3f57ef',
'be5836e03b884da5b4caa34c391aa055',
'd2e2ee13689d4a25965883747c89ee81',
'4541f725834b4735a9093929e2d53f27',
'4dedde2b1103477fac0cbc2e874dc0fc',
'131dce52d4c444e99744cffead9c6745',
'f612eddcc3644940a583b371345d8813',
'7914c0b660354843a1e01a77f5c9f253',
'e71a403a580542c09bf0cbd26fddbf8d',
'380cbcfe3b4c4ae0bc11042aea293bda',
'56b5a46d0f8b4747aa2f68e710b01beb',
'f188d4ffb2764a1cb2a2e521a048230d',
'a6e4b55d9423414ea13da73f333ae203',
'6b58e7c978d84474919fbb508ee74098',
'a9440e8e652045ce93d73024215f6339',
'95d23a23f31e4435a9ec2b4dd7ca95dd',
'fd27984ecdca4fc297eed2c2972aebc3',
'c3436dbfc59b475e9fe212d296555ee0',
'0d1595a291c741839bb63f845013ac61',
'7cb45ac9009543c4a6d8c37768645819',
'4bb39d43151d43afa9e16c4dbcbd4bed',
'1f07902009a044e5bf3ea0b1eeb92f46',
'566a28e327d74ad6a239cd216415eb39',
'27e16fd893e24174a18990d1549e4caa',
'a690b5d7644946eab29c73d7d68496f1',
'99ce5ea8b62e433e8b9411c9a3afb08e',
'6f04eef6f73f48619a4a626e36af56e0',
'0f10ec76bffe43578333648a5f591d58',
'309fc6a495ce4fabb69d92a2b4c5cf05',
'2a67bae5ebb74a2faf8ad74b83bb99a2',
'325f92a692d34d8192cd850742bc0439',
'90d5f70155f748628eb8505cd47150c0',
'90bc75f305af46dda7625617fb4df2aa',
'ea3721e5e1074015b79d44e3d9876aa6',
'0fe9fe6213b44a648be4661bb7da66cd',
'f2872c8cf56c4e25a5cd41bd031c6265',
'e0f6b4cb173c48d9830f55bc0eeb8519',
'fb627a5efacf4c6ea4bd73d0f0e19cda',
'681a2aa741d945fd9a90c48175de3dc5',
'9a3573fb34cf45ddb8791d47a89e4a9c',
'a9841760c7b94ba9ac240887d6c32607',
'bb4a73d7b46748b9a2991897bf42f7f7',
'c130b38bd09a4c0d94398ca4364fc2ed',
'a47d30a0c3aa493aba2463688358c426',
'f43e6886b8a44b2782c50c114df0e87b',
'd4e2f96d66894d33af9a5e19b44cf906',
'7331b2de006945b1a31b73c7fd467b2d',
'f070f1443c3b4cfabf4dd2fc1774d250',
'9ba4e0cc3b5745978a0753988c8abdcf',
'91789a44b5474829a0fb1e7ef8999179',
'c286ccbd8c114c19a16014ad3f45abbc',
'3c61ceb65ec54bc5bc9c8a637b3cbb00',
'2295f5678bda4cdcb5928ff48730d1ed',
'901495f21dd44daf87ef7bffba8fd84c',
'ceee69a63f5a43fdbb94fc19fd128e59',
'cbd9f03e36b24d8c834f1fb2eda2f08c',
'2b27ff6e70ba4186b5b946f5c8215279',
'24cc9c471dc64b8796ab608f5920dbcc',
'ace6fb82dfbc497e888495bc4733ffb6',
'c257e3602d5b4ab195c641a11bb9241f',
'0cb9d29fa7bc4f818633ea82cd80ed2b',
'61ee2045c25b453981b941c865f7eb27',
'71be734642914bd6ad3e194f301631bb',
'f1e7b4097d8945549d682075716224c0',
'123ca145971c48888f33655bd776d25d',
'c813183c31874c1ebf9de8437f7b2905',
'c0f77660213f4c299bcae64916fc59f5',
'22b87521682f4159bfb0bad7ce3f1c64',
'86047f1d5955458289b04f210ef8caa2',
'0b82d53e7db8424d9b9d6dc0d149d11c',
'cfda5539f0fc47579c132bb2eccad6d5',
'dd486f13a58343ea9cdd461bc5eedef5',
'0fa2cba737064e709dae07b5db147088',
'abd15485ce384d78841d06c1d553739d',
'8ad6e9289ab14648a9a2c24c81f071fc',
'758f43773cce4c39ba981deab534e4db',
'679c683710dc480f9206e15ad6d2347d',
'156bbdbd106242a89c0764073b9a10f3',
'ed688fc44fd74db3b202638b149e3777',
'675484f38ffa417590fd725d6e3ed254',
'a2dbc99ee7294130a93c698fd282d076',
'08a1fc2aeae44079a28aa77ccb814cd2']

store_dict = {}

for idx in range(len(brand_data)):
    name = brand_data.iloc[idx]["brandName"]
    logo_imgurl = brand_data.iloc[idx]["brand_user_img_url"]
    banner_imgurl = banner_base_url + banners[idx % 10]
    sql_str += 'INSERT INTO store (provider_id) VALUES (UNHEX("'\
        + store_uuids[idx]\
        +'"));\n'
    store_dict[name] = store_uuids[idx]
    
print(sql_str)
# Out:
# SET AUTOCOMMIT = FALSE;
# INSERT INTO store (provider_id) VALUES (UNHEX("2fe2b6febfbf40d49517b2af0d6e0052"));
# INSERT INTO store (provider_id) VALUES (UNHEX("798bdcef526d476bb17db577c095da3c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0b55eec8b5014020acc65c9b45010d44"));
# INSERT INTO store (provider_id) VALUES (UNHEX("23d83c830df74f82acded17b1ae3df09"));
# INSERT INTO store (provider_id) VALUES (UNHEX("35e94b0c3c504d7cad176dbec3ea5626"));
# INSERT INTO store (provider_id) VALUES (UNHEX("bc794748e6b64d5192c25afe0a9ac413"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7e8b3142dd9c44b5876c102dda41a384"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2c5f79f2690944ed8be10b0b57df694a"));
# INSERT INTO store (provider_id) VALUES (UNHEX("e5f2daa83e274e4e87aebaa1f3f163a5"));
# INSERT INTO store (provider_id) VALUES (UNHEX("b4265a04c4bd484889b1e93a872ffe90"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9e0d88e4c6284249a498efd3668407d4"));
# INSERT INTO store (provider_id) VALUES (UNHEX("41c5e18665974cae88e38b8671102f50"));
# INSERT INTO store (provider_id) VALUES (UNHEX("623cb69a1a8e424b854b590ba147419c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("b31cffe898784ac49595391f8cd09356"));
# INSERT INTO store (provider_id) VALUES (UNHEX("bfdd516dc58e49d9a1a916ea160a5e46"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5a4c6074737b4638b0b7605a23284975"));
# INSERT INTO store (provider_id) VALUES (UNHEX("08b754a63b2f4ef1bdc8ba857f3c0f29"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c7c4aaffc13e48a6b439011bfb3bdef7"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f722ed3613284e72a41755e226c983fa"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f131642faaa240179c203b13ead44e98"));
# INSERT INTO store (provider_id) VALUES (UNHEX("b56b0b12feba4069885ffbef6a4d1e1d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("3f62292302e24602a272cf19ac621e21"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7fae577dd4f24b28be3c0de1ab7f8d97"));
# INSERT INTO store (provider_id) VALUES (UNHEX("b675cd00fee94181bdbbfdd740c0414e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5337192002d2475d821b37d7b023bb11"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2d323455513f4310a7662174ef5ca88f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("806532bb3f604778b28d08f2a205dc30"));
# INSERT INTO store (provider_id) VALUES (UNHEX("8bf2c172e9d543809d88f7db5e948aa9"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9d5f5f914270409390716098d94339d3"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2848b786560d4cc18ce478ddf51d2f06"));
# INSERT INTO store (provider_id) VALUES (UNHEX("983350f5d0bb4e26abd386f534fee12a"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5504925dc8c44022b285dcda79dc5875"));
# INSERT INTO store (provider_id) VALUES (UNHEX("33ff9c46a1724d61ab46d2d320a95f16"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7da30fc012c94ca3b546e8eee143e79b"));
# INSERT INTO store (provider_id) VALUES (UNHEX("faa373f6adab46d8a6e2e8a0409cbee7"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c380016f1a0a4a628185961d256fa62f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("cf9209fd6c9a41f097979775d19f05e6"));
# INSERT INTO store (provider_id) VALUES (UNHEX("3b4faf3fbf8045a9804cb6d582b7f3ca"));
# INSERT INTO store (provider_id) VALUES (UNHEX("eb566a23f5cb4a81930dfc77f6af0543"));
# INSERT INTO store (provider_id) VALUES (UNHEX("fc16a8b85dce4acb94afe9d44a54bd8a"));
# INSERT INTO store (provider_id) VALUES (UNHEX("ce88c0a1944e4baca1aaf3fb96f3a9ab"));
# INSERT INTO store (provider_id) VALUES (UNHEX("18ee419344e84d518130ea7fa470e01a"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4e6ed7c6f15040beb888eca80da59fbb"));
# INSERT INTO store (provider_id) VALUES (UNHEX("62adae397e9c4a10bc280db984611052"));
# INSERT INTO store (provider_id) VALUES (UNHEX("effd2bec68b5431bb7b2d86438aa9ef4"));
# INSERT INTO store (provider_id) VALUES (UNHEX("84f56414f0c24b5bb8fc47ba8b4d64f0"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4d4bc793f005490891631aa39455ee6b"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9f67e3073d6c4d1e906ad1b8eeacb7f1"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5475093cacc3479ca2cd9739aa8e3e1c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("371c7d33ae1a4772af2e020834ee1445"));
# INSERT INTO store (provider_id) VALUES (UNHEX("345169a2541443ea8e642aa61a24fd7d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("b582d0cdbae846049631f6d475a8b38b"));
# INSERT INTO store (provider_id) VALUES (UNHEX("ed6dbf8ee9dd40f3b7442971a2185d9e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("abc73a98caf948dcb7d964d8d6c03caa"));
# INSERT INTO store (provider_id) VALUES (UNHEX("db75e7c1d1ea4ffba8c81d9cbd840628"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4c34c97b3c3d4ba4b49aa853b38baa2f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("8ff4b86beb23498a9247405635166cd8"));
# INSERT INTO store (provider_id) VALUES (UNHEX("06a614f05d7f4afd81f964e857554805"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f61562c4517a47cabe0d5ebb99a180bf"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f20feda7b2f845b2884774213323edf6"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f292a195b34c4d62853f76c4860d9ec4"));
# INSERT INTO store (provider_id) VALUES (UNHEX("bc73c933e3c44b4d971e499215f94844"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7a02811d48c84c3f9372b939fcba109b"));
# INSERT INTO store (provider_id) VALUES (UNHEX("37137e21075a4c43b004987934c2eade"));
# INSERT INTO store (provider_id) VALUES (UNHEX("e848c07ebf1d4a3d84647dd3b284e179"));
# INSERT INTO store (provider_id) VALUES (UNHEX("65b8f6cded8748619544ca732a7ec301"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c96ae42853c845dbaac3d33968dc1911"));
# INSERT INTO store (provider_id) VALUES (UNHEX("da2727f3570a4eabafa5ea40183a7d9d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9873d4f4cd6843c498fd0d35ec497b80"));
# INSERT INTO store (provider_id) VALUES (UNHEX("b67cc7fbcd9447a999e8f6c32c915dcb"));
# INSERT INTO store (provider_id) VALUES (UNHEX("37cb8c06b7364272a916297542a44335"));
# INSERT INTO store (provider_id) VALUES (UNHEX("17ba2706fe364efe9ebda9f2fd219506"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0ae0035320464f4fb6532c931cae7ad3"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a27659805f8a40d89de1c2eea1df91b4"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4d42b516fe274a4793c7d0aa07fbb0af"));
# INSERT INTO store (provider_id) VALUES (UNHEX("eddfbb2a7a834264adb3e923d1b50586"));
# INSERT INTO store (provider_id) VALUES (UNHEX("1366fce6682e46f289510cb501902096"));
# INSERT INTO store (provider_id) VALUES (UNHEX("dffb3d98963f4f24ac9a07cdc812a23e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0ce618210a8f48338c417ff8c58a6125"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2ff5f39afab34029bf7e848683046c1f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f4aaed518e6a44008548a629959eff1e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2abc67ede9af462285118d53f92b3d6d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c77b5d5aae214c55b882f82599cd72a5"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7cf2ca0dcdf24dd2b9902e4c6f08547c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("984b9e72facf43a6b4fe6432696b2a25"));
# INSERT INTO store (provider_id) VALUES (UNHEX("617f9507aaed422fb89714b36e07ecaa"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4e93885d611e49108094eeb98d1388a7"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5f470082bfcb42cab88aa60a66e9b428"));
# INSERT INTO store (provider_id) VALUES (UNHEX("96eb4081140d49239c8aa3c16fe0e19c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("fc152965226449c0a9d7b37638c8300f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("1ffb0c009c2a4c42906ebc8aa4d41e98"));
# INSERT INTO store (provider_id) VALUES (UNHEX("e3d2877deb2349d1b394c504a5a178c9"));
# INSERT INTO store (provider_id) VALUES (UNHEX("d31e7dc543654dc6bc61cbc32c713473"));
# INSERT INTO store (provider_id) VALUES (UNHEX("ab6729cc0a8e4c6794cc68d2d0a7f6d0"));
# INSERT INTO store (provider_id) VALUES (UNHEX("940186abae8c4683872f5ab03155bf76"));
# INSERT INTO store (provider_id) VALUES (UNHEX("fb94f7004d8a4e1ab45e2c6711cf27ff"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a9d61af65a684ef6a1ebbd63e5936a80"));
# INSERT INTO store (provider_id) VALUES (UNHEX("3201d16d4eee436ca5747a135d51cdf2"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9526cfd7767c45db8455cfec60a706ff"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0c88ac262e344c3e8b1d0ace7ec915ea"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0b8bfa4015fb411594e4796352f4181a"));
# INSERT INTO store (provider_id) VALUES (UNHEX("39c5880673054a58ae374d190252083c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("48b91a1d659a4688a46adb043ae38221"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a29e59fbb1834617bc1b4a4e48627c04"));
# INSERT INTO store (provider_id) VALUES (UNHEX("1f0963b429204ce7b597071292ce26f6"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c5b335f6127b42e7a33265ebab6e4249"));
# INSERT INTO store (provider_id) VALUES (UNHEX("6089bd0c16074c5c9f4960129eca75a7"));
# INSERT INTO store (provider_id) VALUES (UNHEX("e24d8081f3b849eeb60f368d603de9b1"));
# INSERT INTO store (provider_id) VALUES (UNHEX("08419c480c03492a92f6dcab024d1ecd"));
# INSERT INTO store (provider_id) VALUES (UNHEX("13957b642aa04ce1a68e8112ac3c86c5"));
# INSERT INTO store (provider_id) VALUES (UNHEX("cf549aacf3d04e0298d9b17c76dd9a1d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2357915085bf4162ba1ae2dc6fa64323"));
# INSERT INTO store (provider_id) VALUES (UNHEX("48ce8c4d0301470f95dff9bf5be053f7"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7dbcc5177e614385b32269dc9a8727a3"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5f78629cb05e4ef29aadb3c54ca96199"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9afa1f646257465f8f37dca7aefd87ce"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2c3126f6fd8f4be0bb5c090675d8c684"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c1b34f14195f41ab84a822f832dd0b98"));
# INSERT INTO store (provider_id) VALUES (UNHEX("37f4ee109bb84b708d48ddc0706b39f8"));
# INSERT INTO store (provider_id) VALUES (UNHEX("14432ac7c3b649149414e749477f4ad6"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9e2610ca516d4935ac3cee1b58f6f290"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7f7f197a1a014424a817582571ce96d0"));
# INSERT INTO store (provider_id) VALUES (UNHEX("177a551e652341b3b5f69187d3626379"));
# INSERT INTO store (provider_id) VALUES (UNHEX("06c8145645d64f809b02bf133b528890"));
# INSERT INTO store (provider_id) VALUES (UNHEX("aa96c5d2c9b54448b21dadb37c3871e3"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f037303106e24aa4888382c6b94a7bc3"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c17b419965af4f48aaa9835984f7634e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("6807efc7f3a54adfa84ce065e4979259"));
# INSERT INTO store (provider_id) VALUES (UNHEX("b1a1e71211e74efb95e5c9685174632f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a3ae668ba5b34bf7a1f649a15e054095"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5feb9e26f2814e718d873724b08d95c5"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9e6a7b8c8e7040289096283736153f6d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("61be0ad8402747d3890e30eed0a1d227"));
# INSERT INTO store (provider_id) VALUES (UNHEX("19d5d863cf334e20a104e03cc18a3b8b"));
# INSERT INTO store (provider_id) VALUES (UNHEX("437ef861e9194fdcb505072f3c0a6125"));
# INSERT INTO store (provider_id) VALUES (UNHEX("e1375072eab24f55bbd2582ba8e4e70f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("d3789ba2156f4cbb816d996a120ad6aa"));
# INSERT INTO store (provider_id) VALUES (UNHEX("51432de0415b41cca65cae6bd92e1a1d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9e6bb0ca121b4bc69722058867c1209e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9c9f090aa6d94577b3fffb2877c0545f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("1f7829aa68964ed38ae5addccf571e8e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2f647082353441a58809ef11e7a07672"));
# INSERT INTO store (provider_id) VALUES (UNHEX("85d07311b1ea488da3bbcd1a11891ff4"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f546b56db7fc4af19af583de4ee27883"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7a7a55500d884bca886fd0782febef56"));
# INSERT INTO store (provider_id) VALUES (UNHEX("872945ce4586453cb07b918cf1a4144e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("59b50af286af468b9f62542a3d448359"));
# INSERT INTO store (provider_id) VALUES (UNHEX("382068a506f945719742fc6a76de9242"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c88f370a271347198c6aa354f716bae4"));
# INSERT INTO store (provider_id) VALUES (UNHEX("df69fd6a61bc4189b2bdd912b3a66387"));
# INSERT INTO store (provider_id) VALUES (UNHEX("680ac9c381e346d7819cdd0623a5e1c6"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c15a7265e950404eaf1d9efdfd9a2a58"));
# INSERT INTO store (provider_id) VALUES (UNHEX("46d8908445e443a2b0cef3a9ce48e111"));
# INSERT INTO store (provider_id) VALUES (UNHEX("d142cdf19bff4edcba755c2d583562b7"));
# INSERT INTO store (provider_id) VALUES (UNHEX("71e20319736d423ca19592a433175ad4"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f53c25e9468c4cb496c1420b872fa654"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4967e7b5c64742168d536bb54e746361"));
# INSERT INTO store (provider_id) VALUES (UNHEX("17ee04fbb06e43aeb03c14881589aed0"));
# INSERT INTO store (provider_id) VALUES (UNHEX("16853cde3cf7416d964d06181c3952a4"));
# INSERT INTO store (provider_id) VALUES (UNHEX("3785d432c2924856895803fbdfc2b5bd"));
# INSERT INTO store (provider_id) VALUES (UNHEX("8c5302e480744937b4ed33eec5da04fb"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7c30aafccd554d33b8bb35a6b741a920"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2679f47ec95a4c558f332b495c02b0f1"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5238750ec6a34183bb15fc5004017142"));
# INSERT INTO store (provider_id) VALUES (UNHEX("1d9452b669714c5b9743cb053a09977f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("ae8c01b49e3c4b0f80fa43edf31f4041"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9cfb606ed2b14f87858e52ea7f3a156e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f5acb8f4cd2242fa9dc1532b986f73af"));
# INSERT INTO store (provider_id) VALUES (UNHEX("3a4c200ad1d043d696ba09e47da64c93"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c20dd3904b124075bc4f0565ea4af907"));
# INSERT INTO store (provider_id) VALUES (UNHEX("5983e2aeffbb46bc9711aca6a437e2aa"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4fea71e43d1d4a9d8e50d964b0bc0ff2"));
# INSERT INTO store (provider_id) VALUES (UNHEX("323392c92a834846a62975138dafe57a"));
# INSERT INTO store (provider_id) VALUES (UNHEX("3a0507b499c34692adacffbdd886343e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("fe99e54a8b3742ec8781b7f88a198f80"));
# INSERT INTO store (provider_id) VALUES (UNHEX("43b357bf8c954eefa90c36f67314dfa6"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9f9c55c9bf6b4a6dba3164bb1300507d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("3ddd757b91084735bfcdfcfb6fca65a8"));
# INSERT INTO store (provider_id) VALUES (UNHEX("08868c5610a44bf3ab7bce3852f0d541"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0bab3bc65e7d4f9bbf7763dcb917d069"));
# INSERT INTO store (provider_id) VALUES (UNHEX("394b2d92f5604a5cac12bb2faf3f57ef"));
# INSERT INTO store (provider_id) VALUES (UNHEX("be5836e03b884da5b4caa34c391aa055"));
# INSERT INTO store (provider_id) VALUES (UNHEX("d2e2ee13689d4a25965883747c89ee81"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4541f725834b4735a9093929e2d53f27"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4dedde2b1103477fac0cbc2e874dc0fc"));
# INSERT INTO store (provider_id) VALUES (UNHEX("131dce52d4c444e99744cffead9c6745"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f612eddcc3644940a583b371345d8813"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7914c0b660354843a1e01a77f5c9f253"));
# INSERT INTO store (provider_id) VALUES (UNHEX("e71a403a580542c09bf0cbd26fddbf8d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("380cbcfe3b4c4ae0bc11042aea293bda"));
# INSERT INTO store (provider_id) VALUES (UNHEX("56b5a46d0f8b4747aa2f68e710b01beb"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f188d4ffb2764a1cb2a2e521a048230d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a6e4b55d9423414ea13da73f333ae203"));
# INSERT INTO store (provider_id) VALUES (UNHEX("6b58e7c978d84474919fbb508ee74098"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a9440e8e652045ce93d73024215f6339"));
# INSERT INTO store (provider_id) VALUES (UNHEX("95d23a23f31e4435a9ec2b4dd7ca95dd"));
# INSERT INTO store (provider_id) VALUES (UNHEX("fd27984ecdca4fc297eed2c2972aebc3"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c3436dbfc59b475e9fe212d296555ee0"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0d1595a291c741839bb63f845013ac61"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7cb45ac9009543c4a6d8c37768645819"));
# INSERT INTO store (provider_id) VALUES (UNHEX("4bb39d43151d43afa9e16c4dbcbd4bed"));
# INSERT INTO store (provider_id) VALUES (UNHEX("1f07902009a044e5bf3ea0b1eeb92f46"));
# INSERT INTO store (provider_id) VALUES (UNHEX("566a28e327d74ad6a239cd216415eb39"));
# INSERT INTO store (provider_id) VALUES (UNHEX("27e16fd893e24174a18990d1549e4caa"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a690b5d7644946eab29c73d7d68496f1"));
# INSERT INTO store (provider_id) VALUES (UNHEX("99ce5ea8b62e433e8b9411c9a3afb08e"));
# INSERT INTO store (provider_id) VALUES (UNHEX("6f04eef6f73f48619a4a626e36af56e0"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0f10ec76bffe43578333648a5f591d58"));
# INSERT INTO store (provider_id) VALUES (UNHEX("309fc6a495ce4fabb69d92a2b4c5cf05"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2a67bae5ebb74a2faf8ad74b83bb99a2"));
# INSERT INTO store (provider_id) VALUES (UNHEX("325f92a692d34d8192cd850742bc0439"));
# INSERT INTO store (provider_id) VALUES (UNHEX("90d5f70155f748628eb8505cd47150c0"));
# INSERT INTO store (provider_id) VALUES (UNHEX("90bc75f305af46dda7625617fb4df2aa"));
# INSERT INTO store (provider_id) VALUES (UNHEX("ea3721e5e1074015b79d44e3d9876aa6"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0fe9fe6213b44a648be4661bb7da66cd"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f2872c8cf56c4e25a5cd41bd031c6265"));
# INSERT INTO store (provider_id) VALUES (UNHEX("e0f6b4cb173c48d9830f55bc0eeb8519"));
# INSERT INTO store (provider_id) VALUES (UNHEX("fb627a5efacf4c6ea4bd73d0f0e19cda"));
# INSERT INTO store (provider_id) VALUES (UNHEX("681a2aa741d945fd9a90c48175de3dc5"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9a3573fb34cf45ddb8791d47a89e4a9c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a9841760c7b94ba9ac240887d6c32607"));
# INSERT INTO store (provider_id) VALUES (UNHEX("bb4a73d7b46748b9a2991897bf42f7f7"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c130b38bd09a4c0d94398ca4364fc2ed"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a47d30a0c3aa493aba2463688358c426"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f43e6886b8a44b2782c50c114df0e87b"));
# INSERT INTO store (provider_id) VALUES (UNHEX("d4e2f96d66894d33af9a5e19b44cf906"));
# INSERT INTO store (provider_id) VALUES (UNHEX("7331b2de006945b1a31b73c7fd467b2d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f070f1443c3b4cfabf4dd2fc1774d250"));
# INSERT INTO store (provider_id) VALUES (UNHEX("9ba4e0cc3b5745978a0753988c8abdcf"));
# INSERT INTO store (provider_id) VALUES (UNHEX("91789a44b5474829a0fb1e7ef8999179"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c286ccbd8c114c19a16014ad3f45abbc"));
# INSERT INTO store (provider_id) VALUES (UNHEX("3c61ceb65ec54bc5bc9c8a637b3cbb00"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2295f5678bda4cdcb5928ff48730d1ed"));
# INSERT INTO store (provider_id) VALUES (UNHEX("901495f21dd44daf87ef7bffba8fd84c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("ceee69a63f5a43fdbb94fc19fd128e59"));
# INSERT INTO store (provider_id) VALUES (UNHEX("cbd9f03e36b24d8c834f1fb2eda2f08c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("2b27ff6e70ba4186b5b946f5c8215279"));
# INSERT INTO store (provider_id) VALUES (UNHEX("24cc9c471dc64b8796ab608f5920dbcc"));
# INSERT INTO store (provider_id) VALUES (UNHEX("ace6fb82dfbc497e888495bc4733ffb6"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c257e3602d5b4ab195c641a11bb9241f"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0cb9d29fa7bc4f818633ea82cd80ed2b"));
# INSERT INTO store (provider_id) VALUES (UNHEX("61ee2045c25b453981b941c865f7eb27"));
# INSERT INTO store (provider_id) VALUES (UNHEX("71be734642914bd6ad3e194f301631bb"));
# INSERT INTO store (provider_id) VALUES (UNHEX("f1e7b4097d8945549d682075716224c0"));
# INSERT INTO store (provider_id) VALUES (UNHEX("123ca145971c48888f33655bd776d25d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c813183c31874c1ebf9de8437f7b2905"));
# INSERT INTO store (provider_id) VALUES (UNHEX("c0f77660213f4c299bcae64916fc59f5"));
# INSERT INTO store (provider_id) VALUES (UNHEX("22b87521682f4159bfb0bad7ce3f1c64"));
# INSERT INTO store (provider_id) VALUES (UNHEX("86047f1d5955458289b04f210ef8caa2"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0b82d53e7db8424d9b9d6dc0d149d11c"));
# INSERT INTO store (provider_id) VALUES (UNHEX("cfda5539f0fc47579c132bb2eccad6d5"));
# INSERT INTO store (provider_id) VALUES (UNHEX("dd486f13a58343ea9cdd461bc5eedef5"));
# INSERT INTO store (provider_id) VALUES (UNHEX("0fa2cba737064e709dae07b5db147088"));
# INSERT INTO store (provider_id) VALUES (UNHEX("abd15485ce384d78841d06c1d553739d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("8ad6e9289ab14648a9a2c24c81f071fc"));
# INSERT INTO store (provider_id) VALUES (UNHEX("758f43773cce4c39ba981deab534e4db"));
# INSERT INTO store (provider_id) VALUES (UNHEX("679c683710dc480f9206e15ad6d2347d"));
# INSERT INTO store (provider_id) VALUES (UNHEX("156bbdbd106242a89c0764073b9a10f3"));
# INSERT INTO store (provider_id) VALUES (UNHEX("ed688fc44fd74db3b202638b149e3777"));
# INSERT INTO store (provider_id) VALUES (UNHEX("675484f38ffa417590fd725d6e3ed254"));
# INSERT INTO store (provider_id) VALUES (UNHEX("a2dbc99ee7294130a93c698fd282d076"));
# INSERT INTO store (provider_id) VALUES (UNHEX("08a1fc2aeae44079a28aa77ccb814cd2"));

# %%
modified_input_excel_path = "raw_fashion_modified.xlsx"
modified_data = pd.read_excel(modified_input_excel_path)

modified_data["colour1"] = modified_data["colour1"].fillna("NA")
modified_data["colour2"] = modified_data["colour2"].fillna("NA")
modified_data["usage"] = modified_data["usage"].fillna("NA")
modified_data["descriptions"] = modified_data["descriptions"].fillna("")

# %%
merchandise_sql = "INSERT INTO merchandise (id, name, imgurl, inventory, created_at, updated_at, base_color_id, color1_id, color2_id, group_id) VALUES (%s, %s, %s, 100, now(), now(), %s, %s, %s, %s)"
merchandise_group_sql = "INSERT INTO merchandise_group (id, description, category_id, type_id, age_gender_group_id, usage_id, price, discounted_price, season, provider_id, fashion_year) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, UNHEX(%s), %s)"
merchandise_additional_img = "INSERT INTO merchandise_additional_img (kind, merchandise_id, imgurl) VALUES (%s, %s, %s)"

group_id, m_id = 0, 0

complete = len(modified_data)
ten_percent = complete // 100
prog = 0
for idx, row in modified_data.iterrows():
    if idx % ten_percent == 0:
        print(f'start ... {prog}% ...')
        prog += 1
    
    if row["articleId"] not in article_dict.keys():
        continue

    styleImages = json.loads(row["styleImages"].replace("\'", "\"").replace('\n', '\\n'))
    if "search" not in styleImages.keys():
        continue

    # merchandise group에 등록
    description = row["descriptions"]
    category_id = article_dict[row["articleId"]][0]
    type_id = article_dict[row["articleId"]][1]
    age_gender_group_id = age_gender_group[row["ageGroup"]][0]
    usage_id = usage[row["usage"]][0]
    price = round(16.32 * 1.5 * row["price"], -3)
    discounted_price = round(16.32 * 1.5 * row["discountedPrice"], -3)
    season_var = season[row["season"]]
    if row["brandName"] == "Adidas":
        provider_id = store_dict["ADIDAS"]
    else:
        provider_id = store_dict[row["brandName"]]
    fashion_year = row["year"]

    # 기본 물품 등록
    merchandise_name = " ".join((row["brandName"], age_gender_group[row["ageGroup"]][1], color[row["baseColour"]][1], article_dict[row["articleId"]][3]))
    imgurl = styleImages["search"]["imageURL"]
    base_color_id = color[row["baseColour"]][0]
    color1_id = color[row["colour1"]][0]
    color2_id = color[row["colour2"]][0]
    
    sql_str += 'INSERT INTO merchandise (id, name, inventory, discounted_price, provider_id) VALUES ('\
        + str(m_id)\
        +', "'+ merchandise_name +'"'\
        +', 100'\
        +', ' + str(discounted_price)\
        +', UNHEX("'+ provider_id +'")'\
        +');\n'

    m_id += 1
    
    # 색만 다른 물품이 있는 경우
    if type(row["colours"]) == str:
        colors = json.loads(row["colours"].replace("\'", "\"").replace('\n', '\\n'))["colors"]
        for ckey in colors.keys():
            baseColour = colors[ckey]["global_attr_base_colour"]
            merchandise_name = " ".join((row["brandName"], age_gender_group[row["ageGroup"]][1], color[baseColour][1], article_dict[row["articleId"]][3]))
            imgurl = colors[ckey]["search_image"]
            Colour1 = colors[ckey]["global_attr_colour1"]
            base_color_id = color[baseColour][0]
            color1_id = color[Colour1][0]
            color2_id = color["NA"][0]
            sql_str += 'INSERT INTO merchandise (id, name, inventory, discounted_price, provider_id) VALUES ('\
                + str(m_id)\
                +', "'+ merchandise_name +'"'\
                +', 100'\
                +', ' + str(discounted_price)\
                +', UNHEX("'+ provider_id +'")'\
                +');\n'
            m_id += 1
    group_id += 1
print()
# Out:
# start ... 0% ...
# start ... 1% ...
# start ... 2% ...
# start ... 3% ...
# start ... 4% ...
# start ... 5% ...
# start ... 6% ...
# start ... 7% ...
# start ... 8% ...
# start ... 9% ...
# start ... 10% ...
# start ... 11% ...
# start ... 12% ...
# start ... 13% ...
# start ... 14% ...
# start ... 15% ...
# start ... 16% ...
# start ... 17% ...
# start ... 18% ...
# start ... 19% ...
# start ... 20% ...
# start ... 21% ...
# start ... 22% ...
# start ... 23% ...
# start ... 24% ...
# start ... 25% ...
# start ... 26% ...
# start ... 27% ...
# start ... 28% ...
# start ... 29% ...
# start ... 30% ...
# start ... 31% ...
# start ... 32% ...
# start ... 33% ...
# start ... 34% ...
# start ... 35% ...
# start ... 36% ...
# start ... 37% ...
# start ... 38% ...
# start ... 39% ...
# start ... 40% ...
# start ... 41% ...
# start ... 42% ...
# start ... 43% ...
# start ... 44% ...
# start ... 45% ...
# start ... 46% ...
# start ... 47% ...
# start ... 48% ...
# start ... 49% ...
# start ... 50% ...
# start ... 51% ...
# start ... 52% ...
# start ... 53% ...
# start ... 54% ...
# start ... 55% ...
# start ... 56% ...
# start ... 57% ...
# start ... 58% ...
# start ... 59% ...
# start ... 60% ...
# start ... 61% ...
# start ... 62% ...
# start ... 63% ...
# start ... 64% ...
# start ... 65% ...
# start ... 66% ...
# start ... 67% ...
# start ... 68% ...
# start ... 69% ...
# start ... 70% ...
# start ... 71% ...
# start ... 72% ...
# start ... 73% ...
# start ... 74% ...
# start ... 75% ...
# start ... 76% ...
# start ... 77% ...
# start ... 78% ...
# start ... 79% ...
# start ... 80% ...
# start ... 81% ...
# start ... 82% ...
# start ... 83% ...
# start ... 84% ...
# start ... 85% ...
# start ... 86% ...
# start ... 87% ...
# start ... 88% ...
# start ... 89% ...
# start ... 90% ...
# start ... 91% ...
# start ... 92% ...
# start ... 93% ...
# start ... 94% ...
# start ... 95% ...
# start ... 96% ...
# start ... 97% ...
# start ... 98% ...
# start ... 99% ...
# start ... 100% ...

# %%
sql_str += 'COMMIT;\n'
sql_str += 'SET AUTOCOMMIT = TRUE;\n'

# %%
print(sql_str.count('\n'))
# Out:
# 56239

# %%
with open('payment_server_import.sql', 'w', encoding='UTF-8') as f:
    f.write(sql_str)
